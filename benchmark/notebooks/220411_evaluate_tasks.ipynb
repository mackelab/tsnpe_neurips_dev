# %%
from benchmark.utils import compile_df

# %%
import matplotlib.pyplot as plt

# %%
df = compile_df("../results/results_thr0")
# Out:
# 0it [00:00, ?it/s]

# %%
df
# Out:
#           task  num_simulations num_observation algorithm        seed  \
# 0    two_moons             1000               1     tsnpe  1670338106
# 1    two_moons            10000               1     tsnpe   978456418
# 2    two_moons            10000               4     tsnpe   746614393
# 3    two_moons           100000               4     tsnpe  2616938119
# 4    two_moons             1000               5     tsnpe  3829767894
# ..         ...              ...             ...       ...         ...
# 103        sir             1000               6     tsnpe  3514959441
# 104        sir             1000               7     tsnpe  2712501502
# 105        sir             1000               8     tsnpe  1850832101
# 106        sir             1000               9     tsnpe   324122784
# 107        sir            10000               1     tsnpe  1539294508
#
#         C2ST   C2ST_Z       MMD     MMD_Z    MEDDIST  ...    MMD_1K  MMD_1K_Z  \
# ...

# %%
slcp_1000 = df.query('task == "slcp" & num_simulations == 1000')["C2ST"].mean()
slcp_10000 = df.query('task == "slcp" & num_simulations == 10000')["C2ST"].mean()
slcp_100000 = df.query('task == "slcp" & num_simulations == 100000')["C2ST"].mean()

# %%
df.query('task == "slcp" & num_simulations == 100000')
# Out:
#     task  num_simulations num_observation algorithm        seed     C2ST  \
# 22  slcp           100000               1     tsnpe   246337487  0.74965
# 26  slcp           100000               2     tsnpe  2205795129  0.77705
# 29  slcp           100000               3     tsnpe    13360207  0.69465
# 32  slcp           100000               4     tsnpe   698258753  0.71530
# 36  slcp           100000               5     tsnpe  2549478936  0.77775
# 39  slcp           100000               6     tsnpe  3964521722  0.74070
# 42  slcp           100000               7     tsnpe  1537823339  0.75390
# 46  slcp           100000               8     tsnpe   300563279  0.76200
# 49  slcp           100000               9     tsnpe  2242830870  0.76255
#
#      C2ST_Z       MMD     MMD_Z    MEDDIST  ...    MMD_1K  MMD_1K_Z  \
# 22  0.73645  0.007975  0.051114  19.343754  ...  0.009042  0.051070
# 26  0.76940  0.011083  0.055841  22.744307  ...  0.010842  0.049542
# ...

# %%
plt.plot([slcp_1000, slcp_10000, slcp_100000])

# %%
tm_1000 = df.query('task == "two_moons" & num_simulations == 1000')["C2ST"].mean()
tm_10000 = df.query('task == "two_moons" & num_simulations == 10000')["C2ST"].mean()
tm_100000 = df.query('task == "two_moons" & num_simulations == 100000')["C2ST"].mean()

# %%
df.query('task == "two_moons" & num_simulations == 100000')
# Out:
#          task  num_simulations num_observation algorithm        seed     C2ST  \
# 3   two_moons           100000               4     tsnpe  2616938119  0.52725
# 6   two_moons           100000               5     tsnpe     5993397  0.54450
# 9   two_moons           100000               6     tsnpe  4247099300  0.52445
# 12  two_moons           100000               1     tsnpe  2931098009  0.52415
# 13  two_moons           100000               7     tsnpe   820957260  0.54590
# 16  two_moons           100000               8     tsnpe   257972540  0.51915
# 19  two_moons           100000               9     tsnpe  1386904077  0.52930
# 45  two_moons           100000               2     tsnpe  3003283649  0.52490
# 52  two_moons           100000               3     tsnpe  1420231767  0.54240
#
#      C2ST_Z       MMD     MMD_Z   MEDDIST  ...    MMD_1K  MMD_1K_Z  \
# 3   0.53170  0.003514  0.003512  0.088833  ...  0.001045  0.001043
# ...

# %%
plt.plot([tm_1000, tm_10000, tm_100000])

# %%
sir_1000 = df.query('task == "sir" & num_simulations == 1000')["C2ST"].mean()
sir_10000 = df.query('task == "sir" & num_simulations == 10000')["C2ST"].mean()
sir_100000 = df.query('task == "sir" & num_simulations == 100000')["C2ST"].mean()

# %%
df.query('task == "sir" & num_simulations == 10000')["path"]
# Out:
# 83     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 84     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 85     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 86     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 87     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 88     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 89     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 90     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 91     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 92     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 94     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 95     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 96     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 97     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 98     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# 99     /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...
# ...

# %%
df.query('task == "sir" & num_simulations == 1000')
# Out:
#     task  num_simulations num_observation algorithm        seed     C2ST  \
# 81   sir             1000               1     tsnpe  2898575271  0.81895
# 82   sir             1000               2     tsnpe  1502547461  0.86025
# 93   sir             1000               3     tsnpe  3382675810  0.69990
# 101  sir             1000               4     tsnpe   894232981  0.52265
# 102  sir             1000               5     tsnpe   266210257  0.50170
# 103  sir             1000               6     tsnpe  3514959441  0.49905
# 104  sir             1000               7     tsnpe  2712501502  0.50055
# 105  sir             1000               8     tsnpe  1850832101  0.61180
# 106  sir             1000               9     tsnpe   324122784  0.62875
#
#       C2ST_Z       MMD     MMD_Z    MEDDIST  ...    MMD_1K  MMD_1K_Z  \
# 81   0.83500  0.469033  0.469253  22.034061  ...  0.480019  0.481411
# 82   0.86615  0.405082  0.395675  51.831460  ...  0.399583  0.392178
# ...

# %%
for i in range(83, 93):
    print(df.query('task == "sir" & num_simulations == 10000')["path"][i])
for i in range(94, 101):
    print(df.query('task == "sir" & num_simulations == 10000')["path"][i])
print(df.query('task == "sir" & num_simulations == 10000')["path"][107])
# Out:
# /mnt/qb/macke/mdeistler57/tsnpe_collection/benchmark/notebooks/../results/results_thr0/2022_04_11/11_16_32_m/10
# /mnt/qb/macke/mdeistler57/tsnpe_collection/benchmark/notebooks/../results/results_thr0/2022_04_11/11_16_32_m/11
# /mnt/qb/macke/mdeistler57/tsnpe_collection/benchmark/notebooks/../results/results_thr0/2022_04_11/11_16_32_m/12
# /mnt/qb/macke/mdeistler57/tsnpe_collection/benchmark/notebooks/../results/results_thr0/2022_04_11/11_16_32_m/13
# /mnt/qb/macke/mdeistler57/tsnpe_collection/benchmark/notebooks/../results/results_thr0/2022_04_11/11_16_32_m/14
# /mnt/qb/macke/mdeistler57/tsnpe_collection/benchmark/notebooks/../results/results_thr0/2022_04_11/11_16_32_m/15
# /mnt/qb/macke/mdeistler57/tsnpe_collection/benchmark/notebooks/../results/results_thr0/2022_04_11/11_16_32_m/16
# /mnt/qb/macke/mdeistler57/tsnpe_collection/benchmark/notebooks/../results/results_thr0/2022_04_11/11_16_32_m/17
# ...

# %%
sir_10000
# Out:
# 0.5203527777777777

# %%
plt.plot([sir_1000, sir_10000, sir_100000])

# %%
gl_1000 = df.query('task == "gaussian_linear" & num_simulations == 1000')["C2ST"].mean()
gl_10000 = df.query('task == "gaussian_linear" & num_simulations == 10000')["C2ST"].mean()
gl_100000 = df.query('task == "gaussian_linear" & num_simulations == 100000')["C2ST"].mean()

# %%
plt.plot([gl_1000, gl_10000, gl_100000])

# %%
lk_1000 = df.query('task == "lotka_volterra" & num_simulations == 1000')["C2ST"].mean()
lk_10000 = df.query('task == "lotka_volterra" & num_simulations == 10000')["C2ST"].mean()
lk_100000 = df.query('task == "lotka_volterra" & num_simulations == 100000')["C2ST"].mean()

# %%
plt.plot([lk_1000, lk_10000, lk_100000])
