# %%
# %load_ext autoreload
# %autoreload 2

# %%
from benchmark.utils import compile_df
from sbibm.visualisation import fig_metric
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# df1 = compile_df("../results/2022_05_09")
# df_full = pd.read_pickle("../results/old_results_thr_point1percent.pkl")
# df_final = pd.concat([df_full, df1])
# df_final.to_pickle("../results/results_thr_point1percent.pkl")

# %%
df1
# Out:
#              task  num_simulations num_observation algorithm        seed  \
# 0  lotka_volterra           100000               4     tsnpe  1207996132
#
#                                      acceptance rate  \
# 0  [1.0, -2.774517059326172, -3.5364322662353516,...
#
#                                        gt in support  C2ST       MMD  \
# 0  [1.0, 0.9973999857902527, 1.0, 1.0, 1.0, 1.0, ...  0.69  0.075769
#
#       MEDDIST  NLTP           RT num_simulations_simulator  \
# 0  117.206085   NaN  1541.802344                  100000.0
#
#                                                 path folder
# 0  /mnt/qb/macke/mdeistler57/tsnpe_collection/ben...      0

# %%
df_final.query("task == 'lotka_volterra' & num_simulations == 100000")
# Out:
#               task  num_simulations  num_observation algorithm        seed  \
# 26  lotka_volterra           100000                1     tsnpe   372294786
# 29  lotka_volterra           100000                2     tsnpe  2458177273
# 32  lotka_volterra           100000                3     tsnpe  3790904672
# 38  lotka_volterra           100000                5     tsnpe  2891279120
# 41  lotka_volterra           100000                6     tsnpe  4225711023
# 45  lotka_volterra           100000                7     tsnpe  3072735103
# 48  lotka_volterra           100000                8     tsnpe  2390841930
# 51  lotka_volterra           100000                9     tsnpe  4254827429
# 54  lotka_volterra           100000               10     tsnpe   473694690
# 0   lotka_volterra           100000                4     tsnpe  1207996132
#
#                                       acceptance rate  \
# 26  [1.0, -1.7484685182571411, -2.1212968826293945...
# ...

# %%
# df1 = compile_df("../results/2022_05_08/17_13_26_m")
# df2 = compile_df("../results/2022_05_08/21_08_02_m")
# df_full = pd.read_pickle("../results/results_thr3_compiled_with_lotka.pkl")
# df_final = pd.concat([df1, df2, df_full])
# df_final.to_pickle("../results/results_thr_point01percent.pkl")
# print(len(df_full))

# %%
# df2 = compile_df("../results/2022_05_08/17_16_03_m")
# df_full = pd.read_pickle("../results/results_sir_with_acceptance.pkl")

# df_final = pd.concat([df_full, df2])
# df_final.to_pickle("../results/results_sir_with_acceptance_final.pkl")

# %%
# df3 = compile_df("../results/2022_05_08/23_18_06_m")
# df_full = pd.read_pickle("../results/results_thr_point1percent.pkl")
# print(len(df_full))

# %%
# df.to_pickle("../results/results_sir_with_acceptance.pkl")

# %%
import pandas as pd
df_full = df

# %%
results_subset = df.query("task == 'gaussian_linear'")
fig_metric(results_subset, metric="C2ST")
# Out:
# alt.FacetChart(...)

# %%
results_subset = df.query("task == 'slcp'")
fig_metric(results_subset, metric="C2ST")
# Out:
# alt.FacetChart(...)

# %%
results_subset = df.query("task == 'two_moons'")
fig_metric(results_subset, metric="C2ST")
# Out:
# alt.FacetChart(...)

# %%
results_subset = df.query("task == 'sir'")
fig_metric(results_subset, metric="C2ST")
# Out:
# alt.FacetChart(...)

# %%
results_subset = df.query("task == 'bernoulli_glm'")
fig_metric(results_subset, metric="C2ST")
# Out:
# alt.FacetChart(...)

# %%
df_full.to_pickle("../results/results_thr3_compiled_with_lotka.pkl")
